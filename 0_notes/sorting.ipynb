# %% [markdown]
# # Sorting Algorithms
#
# ### Goal
# Arrange elements in order
#
# ### Types
# - Comparison-based
# - Non-comparison-based

# %%
# Bubble Sort

def bubble_sort(arr):
    n = len(arr)
    
    for i in range(n):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

# Time: O(n²)
# Idea: swap adjacent elements

# %%
# Insertion Sort

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        
        arr[j + 1] = key

# Time: O(n²)
# Idea: insert into sorted portion

# %%
# Selection Sort

def selection_sort(arr):
    for i in range(len(arr)):
        min_idx = i
        
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[min_idx]:
                min_idx = j
        
        arr[i], arr[min_idx] = arr[min_idx], arr[i]

# Time: O(n²)
# Idea: repeatedly pick minimum

# %%
# Merge Sort

def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    
    result.extend(left[i:])
    result.extend(right[j:])
    
    return result

# Time: O(n log n)
# Idea: divide + merge

# %%
# Quick Sort

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    
    pivot = arr[len(arr) // 2]
    
    left = [x for x in arr if x < pivot]
    mid = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    
    return quick_sort(left) + mid + quick_sort(right)

# Avg: O(n log n)
# Worst: O(n²)
# Idea: partition around pivot

# %%
# Counting Sort

def counting_sort(arr):
    max_val = max(arr)
    count = [0] * (max_val + 1)
    
    for num in arr:
        count[num] += 1
    
    result = []
    for i in range(len(count)):
        result.extend([i] * count[i])
    
    return result

# Time: O(n + k)
# Idea: count frequencies

# %% [markdown]
# ### Summary Table
#
# Bubble → O(n²)
# Insertion → O(n²)
# Selection → O(n²)
# Merge → O(n log n)
# Quick → O(n log n) avg
# Counting → O(n + k)
