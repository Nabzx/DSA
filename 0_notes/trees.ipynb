# %% [markdown]
# # Trees
#
# ### Definition
# - Hierarchical data structure
# - Nodes connected by edges
#
# ### Binary Tree
# - Each node has at most 2 children
#
# ### Terms
# - root, leaf, height, depth

# %%
# Node Structure
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %% [markdown]
# ### Tree properties
# - Height = max depth
# - Balanced vs unbalanced
# - Complete tree

# %% [markdown]
# ### Traversals
# DFS:
# - Preorder: root → left → right
# - Inorder: left → root → right
# - Postorder: left → right → root
#
# BFS:
# - Level order (top to bottom)

# %% [markdown]
# ### Binary Search Tree
#
# #### Property
# left < root < right
#
# #### Inorder traversal → sorted order

# %% [markdown]
# ### Key Insight
# Most tree problems = recursion or BFS
